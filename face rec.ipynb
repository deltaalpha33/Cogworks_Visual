# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

# %%
from visual import *

# %%
me = Photo()
me.load_from_camera()
me.display_picture_with_boxes()
len(me.faces)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 0

# %%
db = Photo_Database()
db.load_saved_images()
db.database
# Out:
# photo_db/Robin Williams
# photo_db/Tom Hanks
# ...

# %%
test = Photo()
test.load_from_file("/home/delta/mit-course/git/Cogworks_Visual/photo_db/Tom Hanks/tom_hanks_getty.jpg")
test.find_faces()
test.display_picture_with_boxes()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
db.label_photo(test)
test.display_picture_with_boxes()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
db.load_photo_from_camera()
db.current_photo.display_picture_with_boxes()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
db.input_unknown_labels()

# %%
db.current_photo.display_picture_with_boxes()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-5bdedd797720> in <module>()
# ----> 1 db.add_current_photo()
#
# AttributeError: 'Photo_Database' object has no attribute 'add_current_photo'

# %%
db.save_database()
